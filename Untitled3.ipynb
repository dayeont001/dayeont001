# %% [markdown]
# <a href="https://colab.research.google.com/github/dayeont001/dayeont001/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://dayeont001: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@github.com/dayeont001/dayeont001.git
# Out:
# Cloning into 'dayeont001'...
# ...
